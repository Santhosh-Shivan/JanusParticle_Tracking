# %%
# !pip install deeptrack
# Out:
# Collecting deeptrack
#   Downloading deeptrack-0.11.3-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 2.1 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from deeptrack) (1.19.5)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.13.0-cp37-cp37m-manylinux2010_x86_64.whl (679 kB)
#      |████████████████████████████████| 679 kB 11.0 MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from deeptrack) (1.4.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from deeptrack) (2.5.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (1.6.3)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (1.34.1)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (3.1.0)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (0.4.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (2.5.0)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (2.5.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (1.12.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (1.1.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (3.3.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (1.1.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (3.17.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (1.12)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (0.36.2)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (2.5.0.dev2021032900)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (3.7.4.3)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->deeptrack) (0.2.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow->deeptrack) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->deeptrack) (0.6.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->deeptrack) (1.32.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->deeptrack) (3.3.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->deeptrack) (0.4.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->deeptrack) (57.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->deeptrack) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->deeptrack) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->deeptrack) (1.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->deeptrack) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->deeptrack) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->deeptrack) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->deeptrack) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow->deeptrack) (4.6.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->deeptrack) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->deeptrack) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->deeptrack) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->deeptrack) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->deeptrack) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->deeptrack) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow->deeptrack) (3.5.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons->deeptrack) (2.7.1)
# Installing collected packages: tensorflow-addons, deeptrack
# Successfully installed deeptrack-0.11.3 tensorflow-addons-0.13.0

# %%
import matplotlib.pyplot as plt
import deeptrack as dt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Simulating(2-D representation) Janus Particle 3d orientation with azimuthal and polar angle

# %%
IMAGE_SIZE = 128


class DarkBrightParticle(dt.Feature):

    def get(self, image, position, radius, intensityOfBright, rotation, **kwargs):
        X, Y = np.meshgrid(np.arange(image.shape[0]), np.arange(image.shape[1]))
        mask = ((X - position[0]) ** 2 + (Y - (position[1])) ** 2 <= radius ** 2)*1.0
        # rotation[1] 0 to 90
        if rotation[1] >= 0 and rotation[1] <= np.pi / 2:
            line_center = [position[0] + int(radius * rotation[1] / (np.pi / 2) * np.cos(rotation[0] - np.pi / 2)),
                           position[1] - int(radius * rotation[1] / (np.pi / 2) * np.sin(rotation[0] - np.pi / 2))]

            if np.sin(rotation[0]) == 1:
                for y in range(image.shape[1]):
                    for x in range(image.shape[0]):
                        if mask[y, x]:
                            if x >= int(line_center[0]):
                                mask[y, x] = intensityOfBright
            elif np.sin(rotation[0]) == -1:
                for y in range(image.shape[1]):
                    for x in range(image.shape[0]):
                        if mask[y, x]:
                            if x <= int(line_center[0]):
                                mask[y, x] = intensityOfBright
            else:
                for y in range(image.shape[0]):
                    for x in range(image.shape[1]):
                        if mask[y, x]:
                            if (np.sin(rotation[0]) >= 0 and np.cos(rotation[0]) > 0) or (
                                    np.sin(rotation[0]) < 0 and np.cos(rotation[0]) > 0):
                                if (y - (line_center[1])) > np.tan(np.pi - rotation[0]) * (x - (line_center[0])):
                                    mask[y, x] = intensityOfBright
                            elif (np.sin(rotation[0]) >= 0 and np.cos(rotation[0]) < 0) or (
                                    np.sin(rotation[0]) < 0 and np.cos(rotation[0]) < 0):
                                if (y - (line_center[1])) < np.tan(np.pi - rotation[0]) * (x - (line_center[0])):
                                    mask[y, x] = intensityOfBright

        
        # rotation[1] -90 to 0
        if rotation[1] < 0  and rotation[1] >= -1* np.pi/2:
            
            line_center = [position[0] - int(radius * (-1*rotation[1]) / (np.pi / 2) * np.cos(
                rotation[0] - np.pi / 2)) , position[1] + int(
                radius * (-1*rotation[1]) / (np.pi / 2) * np.sin(
                    rotation[0] - np.pi / 2)) ]


            if np.sin(rotation[0]) == 1:
                for y in range(image.shape[1]):
                    for x in range(image.shape[0]):
                        if mask[y, x]:
                            if x >= int(line_center[0]):
                                mask[y, x] = intensityOfBright
            elif np.sin(rotation[0]) == -1:
                for y in range(image.shape[1]):
                    for x in range(image.shape[0]):
                        if mask[y, x]:
                            if x <= int(line_center[0]):
                                mask[y, x] = intensityOfBright
            else:
                for y in range(image.shape[0]):
                    for x in range(image.shape[1]):
                        if mask[y, x]:
                            if (np.sin(rotation[0]) > 0 and np.cos(rotation[0]) > 0) or (
                                    np.sin(rotation[0]) < 0 and np.cos(rotation[0]) > 0):
                                if (y - (line_center[1])) > -1*np.tan(rotation[0]) * (x - (line_center[0])):
                                    mask[y, x] = intensityOfBright
                            elif (np.sin(rotation[0]) > 0 and np.cos(rotation[0]) < 0) or (np.sin(rotation[0]) < 0 and np.cos(rotation[0]) < 0):
                                if (y - (line_center[1])) < -1*np.tan(rotation[0] ) * (x - (line_center[0])):
                                    mask[y, x] = intensityOfBright

        mask  = -1*(mask - 1)
        
        return mask
    

class Updater(dt.Feature):
    
    __distributed__ = False
    
    def __init__(self, feature=None, **kwargs):
        super().__init__(features=feature, **kwargs)
        
    def get(self, image, features, **kwargs):
        return features.resolve(
            np.ones(
                (IMAGE_SIZE,IMAGE_SIZE)
                )
            )


particle = DarkBrightParticle(
    position=lambda: (np.random.rand(2) * (40)).astype(int) + 40,
    radius=lambda: 7 + np.random.rand()*1.5,
    rotation = lambda: np.array([np.random.rand()*2*np.pi, np.random.rand()*np.pi/2]),# if np.random.randint(2) == 0 else np.random.rand()*-1*np.pi/2 ]),
    intensityOfBright=0.3
)


gradient = dt.IlluminationGradient(
    gradient=lambda: np.random.randn(2) * 3e-3,#[2e-3, 2e-3],
)

normalization = dt.NormalizeMinMax(0, 1)
gauss = dt.Gaussian(mu = 0, sigma = .1)

circles = particle 
circles = Updater(circles)
import scipy

#Smoothing
kernel = np.ones((5, 5)) / 15
smoothing = dt.Lambda(lambda: lambda image: scipy.ndimage.filters.convolve(image, kernel)) 

circles += smoothing + gradient + gauss + normalization

# %%
def get_label(image):
    angle = np.array(image.get_property("rotation", get_one=False))
    return (np.sin(angle[0, 0]), np.cos(angle[0, 0]), np.sin(angle[0, 1]), np.cos(angle[0, 1]) )

# %%
#Example Simulation Images
NUMBER_OF_IMAGES = 10

for _ in range(NUMBER_OF_IMAGES):
    circles.update()
    image_of_particle = circles.resolve()
    label = get_label(image_of_particle)

    #Calculating Azimuthal Angle(0-360)
    if label[1] == 0 and label[0] == 1:
        ang1 = np.pi/2*180/np.pi
    elif label[1] == 0 and label[0] == -1:
        ang1 = 3*np.pi/2*180/np.pi
    else:
            
        if label[0]>0 and label[1]>0:
            ang1 = np.arctan(label[0]/label[1])*180/np.pi
        elif label[0]>0 and label[1]<0:
            ang1 = (np.arctan(label[0]/label[1])+np.pi)*180/np.pi
        elif label[0]<0 and label[1]<0:
            ang1 = (np.arctan(label[0]/label[1])+np.pi)*180/np.pi
        elif label[0]<0 and label[1]>0:
            ang1 = (np.arctan(label[0]/label[1])+2*np.pi)*180/np.pi

    #Calculating Polar angle(0-90)
    if label[3] == 0 and label[2] == 1:
        ang2 = np.pi/2*180/np.pi
    elif label[3] == 0 and label[2] == -1:
        ang2 = -1*np.pi/2*180/np.pi
    
    else:
        ang2 = np.arctan(label[2]/label[3])*180/np.pi
    
    
    plt.imshow(image_of_particle, cmap="gray")
    plt.colorbar()
    plt.title("Azimuthal = %.1f and Polar = %.1f" %(ang1, ang2))

    plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/deeptrack/optics.py:681: RuntimeWarning: invalid value encountered in true_divide
#   image = amplitude * image / np.abs(image)

# %% [markdown]
# # Defining the Network

# %%
# Defining the NEtwork
import keras.backend as K
import keras.optimizers as optimizers
import tensorflow as tf

model = dt.models.Convolutional(
    input_shape=(IMAGE_SIZE, IMAGE_SIZE, 1),
    conv_layers_dimensions=(16, 32, 64, 64),
    dense_layers_dimensions=(32, 32),
    steps_per_pooling=1,
    number_of_outputs=4,
    loss="mse",
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    convolution_block=dt.layers.ConvolutionalBlock(kernel_size=5),
    dense_block=dt.layers.DenseBlock(activation="relu"),
    pooling_block=dt.layers.PoolingBlock(padding="valid")
)


model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 128, 128, 16)      416
# _________________________________________________________________
# activation (Activation)      (None, 128, 128, 16)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        12832
# _________________________________________________________________
# activation_1 (Activation)    (None, 64, 64, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        51264
# _________________________________________________________________
# activation_2 (Activation)    (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        102464
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                131104
# _________________________________________________________________
# activation_4 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# activation_5 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 132
# =================================================================
# Total params: 299,268
# Trainable params: 299,268
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Training the network

# %%
# Training the model

TRAIN_MODEL = True

from tensorflow.keras.callbacks import EarlyStopping

validation_set_size = 200

validation_set = [circles.update().resolve()  for _ in range(validation_set_size)]
validation_labels = [get_label(image) for image in validation_set]

if TRAIN_MODEL:
    generator = dt.generators.ContinuousGenerator(
        circles,
        get_label,
        min_data_size=int(1e+4),
        max_data_size=int(2e+4),
        batch_size=64
        
    )

    histories = []

    with generator:
        h = model.fit(
            generator,
            validation_data=(
                np.array(validation_set),
                np.array(validation_labels)
            ),
            callbacks=[
                EarlyStopping(patience=20, restore_best_weights=True)
            ],
            epochs=150
        )

    plt.plot(h.history["loss"], 'g')
    plt.plot(h.history["val_loss"], 'r')
    plt.legend(["loss", "val_loss"])
    plt.yscale('log')
    plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/deeptrack/optics.py:681: RuntimeWarning: invalid value encountered in true_divide
#   image = amplitude * image / np.abs(image)
# Generating 10005 / 10000 samples before starting training
# Epoch 1/150
# 156/156 [==============================] - 6s 34ms/step - loss: 0.3944 - val_loss: 0.3802
# Epoch 2/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.3277 - val_loss: 0.2806
# Epoch 3/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.2637 - val_loss: 0.2676
# Epoch 4/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.2575 - val_loss: 0.2639
# Epoch 5/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.2512 - val_loss: 0.2580
# Epoch 6/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.2317 - val_loss: 0.2225
# Epoch 7/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.1793 - val_loss: 0.1644
# Epoch 8/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.1555 - val_loss: 0.1516
# Epoch 9/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.1407 - val_loss: 0.1327
# Epoch 10/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.1106 - val_loss: 0.0979
# Epoch 11/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0778 - val_loss: 0.0765
# Epoch 12/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0654 - val_loss: 0.0641
# Epoch 13/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0591 - val_loss: 0.0610
# Epoch 14/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0578 - val_loss: 0.0567
# Epoch 15/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0534 - val_loss: 0.0635
# Epoch 16/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0517 - val_loss: 0.0537
# Epoch 17/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0503 - val_loss: 0.0507
# Epoch 18/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0476 - val_loss: 0.0519
# Epoch 19/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0468 - val_loss: 0.0520
# Epoch 20/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0458 - val_loss: 0.0472
# Epoch 21/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0445 - val_loss: 0.0559
# Epoch 22/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0449 - val_loss: 0.0447
# Epoch 23/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0420 - val_loss: 0.0443
# Epoch 24/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0409 - val_loss: 0.0437
# Epoch 25/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0412 - val_loss: 0.0433
# Epoch 26/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0397 - val_loss: 0.0406
# Epoch 27/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0392 - val_loss: 0.0393
# Epoch 28/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0369 - val_loss: 0.0407
# Epoch 29/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0377 - val_loss: 0.0392
# Epoch 30/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0386 - val_loss: 0.0415
# Epoch 31/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0375 - val_loss: 0.0421
# Epoch 32/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0358 - val_loss: 0.0444
# Epoch 33/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0352 - val_loss: 0.0381
# Epoch 34/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0340 - val_loss: 0.0369
# Epoch 35/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0335 - val_loss: 0.0366
# Epoch 36/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0339 - val_loss: 0.0380
# Epoch 37/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0329 - val_loss: 0.0344
# Epoch 38/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0324 - val_loss: 0.0319
# Epoch 39/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0312 - val_loss: 0.0319
# Epoch 40/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0307 - val_loss: 0.0347
# Epoch 41/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0304 - val_loss: 0.0394
# Epoch 42/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0299 - val_loss: 0.0303
# Epoch 43/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0295 - val_loss: 0.0310
# Epoch 44/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0291 - val_loss: 0.0277
# Epoch 45/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0272 - val_loss: 0.0324
# Epoch 46/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0280 - val_loss: 0.0318
# Epoch 47/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0269 - val_loss: 0.0263
# Epoch 48/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0270 - val_loss: 0.0296
# Epoch 49/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0258 - val_loss: 0.0261
# Epoch 50/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0260 - val_loss: 0.0253
# Epoch 51/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0257 - val_loss: 0.0229
# Epoch 52/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0249 - val_loss: 0.0241
# Epoch 53/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0238 - val_loss: 0.0314
# Epoch 54/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0233 - val_loss: 0.0253
# Epoch 55/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0237 - val_loss: 0.0238
# Epoch 56/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0235 - val_loss: 0.0241
# Epoch 57/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0220 - val_loss: 0.0214
# Epoch 58/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0225 - val_loss: 0.0217
# Epoch 59/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0215 - val_loss: 0.0239
# Epoch 60/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0210 - val_loss: 0.0198
# Epoch 61/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0200 - val_loss: 0.0218
# Epoch 62/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0206 - val_loss: 0.0208
# Epoch 63/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0194 - val_loss: 0.0201
# Epoch 64/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0204 - val_loss: 0.0184
# Epoch 65/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0189 - val_loss: 0.0175
# Epoch 66/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0191 - val_loss: 0.0169
# Epoch 67/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0177 - val_loss: 0.0203
# Epoch 68/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0173 - val_loss: 0.0175
# Epoch 69/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0171 - val_loss: 0.0170
# Epoch 70/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0174 - val_loss: 0.0170
# Epoch 71/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0169 - val_loss: 0.0163
# Epoch 72/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0157 - val_loss: 0.0190
# Epoch 73/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0166 - val_loss: 0.0172
# Epoch 74/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0158 - val_loss: 0.0144
# Epoch 75/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0155 - val_loss: 0.0149
# Epoch 76/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0151 - val_loss: 0.0143
# Epoch 77/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0158 - val_loss: 0.0154
# Epoch 78/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0141 - val_loss: 0.0122
# Epoch 79/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0136 - val_loss: 0.0137
# Epoch 80/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0139 - val_loss: 0.0160
# Epoch 81/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0159 - val_loss: 0.0135
# Epoch 82/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0134 - val_loss: 0.0125
# Epoch 83/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0130 - val_loss: 0.0112
# Epoch 84/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0126 - val_loss: 0.0151
# Epoch 85/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0123 - val_loss: 0.0112
# Epoch 86/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0130 - val_loss: 0.0146
# Epoch 87/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0119 - val_loss: 0.0149
# Epoch 88/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0122 - val_loss: 0.0154
# Epoch 89/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0120 - val_loss: 0.0127
# Epoch 90/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0122 - val_loss: 0.0103
# Epoch 91/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0110 - val_loss: 0.0099
# Epoch 92/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0113 - val_loss: 0.0113
# Epoch 93/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0116 - val_loss: 0.0095
# Epoch 94/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0114 - val_loss: 0.0124
# Epoch 95/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0098 - val_loss: 0.0092
# Epoch 96/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0102 - val_loss: 0.0136
# Epoch 97/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0100 - val_loss: 0.0093
# Epoch 98/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0102 - val_loss: 0.0129
# Epoch 99/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0097 - val_loss: 0.0090
# Epoch 100/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0095 - val_loss: 0.0098
# Epoch 101/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0091 - val_loss: 0.0083
# Epoch 102/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0093 - val_loss: 0.0114
# Epoch 103/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0091 - val_loss: 0.0076
# Epoch 104/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0092 - val_loss: 0.0076
# Epoch 105/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0082 - val_loss: 0.0071
# Epoch 106/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0087 - val_loss: 0.0085
# Epoch 107/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0094 - val_loss: 0.0087
# Epoch 108/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0079 - val_loss: 0.0076
# Epoch 109/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 110/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0078 - val_loss: 0.0093
# Epoch 111/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0086 - val_loss: 0.0078
# Epoch 112/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0083 - val_loss: 0.0063
# Epoch 113/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0072 - val_loss: 0.0083
# Epoch 114/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0073 - val_loss: 0.0062
# Epoch 115/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 116/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 117/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0071 - val_loss: 0.0060
# Epoch 118/150
# 156/156 [==============================] - 5s 30ms/step - loss: 0.0067 - val_loss: 0.0075
# Epoch 119/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 120/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0063 - val_loss: 0.0052
# Epoch 121/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0059 - val_loss: 0.0091
# Epoch 122/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0063 - val_loss: 0.0055
# Epoch 123/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0061 - val_loss: 0.0066
# Epoch 124/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0058 - val_loss: 0.0050
# Epoch 125/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0058 - val_loss: 0.0048
# Epoch 126/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0055 - val_loss: 0.0046
# Epoch 127/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 128/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 129/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 130/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0060 - val_loss: 0.0063
# Epoch 131/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0058 - val_loss: 0.0042
# Epoch 132/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0056 - val_loss: 0.0047
# Epoch 133/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0065 - val_loss: 0.0045
# Epoch 134/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0052 - val_loss: 0.0082
# Epoch 135/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 136/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 137/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0050 - val_loss: 0.0045
# Epoch 138/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0048 - val_loss: 0.0043
# Epoch 139/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0043 - val_loss: 0.0038
# Epoch 140/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0048 - val_loss: 0.0103
# Epoch 141/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0048 - val_loss: 0.0039
# Epoch 142/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 143/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0046 - val_loss: 0.0039
# Epoch 144/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 145/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0043 - val_loss: 0.0037
# Epoch 146/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0040 - val_loss: 0.0041
# Epoch 147/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0039 - val_loss: 0.0037
# Epoch 148/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0042 - val_loss: 0.0042
# Epoch 149/150
# 156/156 [==============================] - 5s 32ms/step - loss: 0.0041 - val_loss: 0.0035
# Epoch 150/150
# 156/156 [==============================] - 5s 31ms/step - loss: 0.0041 - val_loss: 0.0046

# %%
model.save("/content/drive/MyDrive/3dOrientation_NetworkAngle1")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/3dOrientation_NetworkAngle5/assets

# %% [markdown]
# ## Testing the network on simulated images

# %%
model.load_weights("/content/drive/MyDrive/3dOrientation_NetworkAngle1")

# %%
n_images = 15

image_of_particle = []
for _ in range(n_images):
    circles.update()
    image_of_particle.append(circles.resolve())

img = np.array(image_of_particle)
# Out:
# /usr/local/lib/python3.7/dist-packages/deeptrack/optics.py:681: RuntimeWarning: invalid value encountered in true_divide
#   image = amplitude * image / np.abs(image)

# %%
prediction = model.predict(img)

for i in range(len(img)):
    #Calculating Azimuthal Angle in degrees(0-360)
    if prediction[i,1] == 0 and prediction[i,0] == 1:
        azimuthal_ang = np.pi/2*180/np.pi
    elif prediction[i,1] == 0 and prediction[i,0] == -1:
        azimuthal_ang = 3*np.pi/2*180/np.pi
    else:

        if prediction[i,0]>0 and prediction[i,1]>0:
            azimuthal_ang = np.arctan(prediction[i,0]/prediction[i,1])*180/np.pi
        elif prediction[i,0]>0 and prediction[i,1]<0:
            azimuthal_ang = (np.arctan(prediction[i,0]/prediction[i,1])+np.pi)*180/np.pi
        elif prediction[i,0]<0 and prediction[i,1]<0:
            azimuthal_ang = (np.arctan(prediction[i,0]/prediction[i,1])+np.pi)*180/np.pi
        elif prediction[i,0]<0 and prediction[i,1]>0:
            azimuthal_ang = (np.arctan(prediction[i,0]/prediction[i,1])+2*np.pi)*180/np.pi
    
    #Calculating Polar Angle in degrees(0-90)
    if prediction[i,3] == 0 and prediction[i,2] == 1:
        ang2 = np.pi/2*180/np.pi
    elif prediction[i,3] == 0 and prediction[i,2] == -1:
        ang2 = -1*np.pi/2*180/np.pi
    else:
        ang2 = np.arctan(prediction[i,2]/prediction[i,3])*180/np.pi
    
    plt.imshow(img[i], cmap="gray")
    plt.title("Azimuthal = %.1f and Polar = %.1f" %(azimuthal_ang, ang2))
    plt.colorbar()
    
    plt.show()
